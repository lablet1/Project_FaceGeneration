# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import matplotlib.pyplot as plt
import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader
import numpy as np
from torch.nn import init

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([transforms.RandomHorizontalFlip(0.5), 
                                    transforms.RandomRotation(10),
                                    transforms.ToTensor()])
    
    source_path = './processed-celeba-small'
    train_dataset = datasets.ImageFolder(source_path, transform)
    
    return DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should see square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, int(plot_size/2), idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    bot, top = feature_range
    return x * (top - bot) + bot

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F
global_kernal_size = 4

# %%
def conv(in_channels, out_channels, kernel_size=global_kernal_size, stride=2, padding=1, batch_norm=True):
# -------------------------------------------------------------------------------
#     Creates a convolutional layer, with optional batch normalization.
# -------------------------------------------------------------------------------

    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
#         self.conv1 = conv(3, conv_dim, kernel_size = 3,  stride = 1, padding = 1, batch_norm = False)
        self.conv2 = conv(3, conv_dim, batch_norm = False)
        self.conv3 = conv(conv_dim, conv_dim*2)
        self.conv4 = conv(conv_dim*2, conv_dim*4)
        self.fc = nn.Linear(conv_dim * (4**3), 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        leaky_slope = 0.2
#         x = self.conv1(x)
#         x = F.leaky_relu(x, leaky_slope)
        x = self.conv2(x)
        x = F.leaky_relu(x, leaky_slope)
        x = self.conv3(x)
        x = F.leaky_relu(x, leaky_slope)
        x = self.conv4(x)
        x = F.leaky_relu(x, leaky_slope)
        x = x.view(-1,self.conv_dim * (4**3))
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size=global_kernal_size, stride=2, padding=1, batch_norm=True):
# -------------------------------------------------------------------------------
#     Creates a transposed-convolutional layer, with optional batch normalization.
# -------------------------------------------------------------------------------
    
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(transpose_conv_layer)
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
     
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size, conv_dim * (4**2))
#         self.deconvB = deconv(conv_dim*16, conv_dim*16, kernel_size = 3, stride = 1)
        self.deconvA = deconv(conv_dim*16, conv_dim*8)
        self.deconv0 = deconv(conv_dim*8, conv_dim*4)
        self.deconv1 = deconv(conv_dim*4, conv_dim*2)
        self.deconv2 = deconv(conv_dim*2, conv_dim)
        self.deconv3 = deconv(conv_dim, 3, batch_norm = False)
#         self.deconv4 = deconv(conv_dim, 3, kernel_size = 3,  stride = 1, padding = 1, batch_norm = False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*16, 1, 1)
#         x = self.deconvB(x)
#         x = F.relu(x)
        x = self.deconvA(x)
        x = F.relu(x)
        x = self.deconv0(x)
        x = F.relu(x)
        x = self.deconv1(x)
        x = F.relu(x)
        x = self.deconv2(x)
        x = F.relu(x)
        x = self.deconv3(x)
#         x = F.relu(x)
#         x = self.deconv4(x)
        x = torch.tanh(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # TODO: Apply initial weights to convolutional and linear layers
    mean = 0
    std = 0.02
    for module in m.modules():
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight.data, mean, std)
            nn.init.constant_(module.bias.data, 0)
#             print(module)
        elif isinstance(module, nn.Conv2d) or isinstance(module, nn.ConvTranspose2d):
            nn.init.normal_(module.weight.data, mean, std)
#             print(module)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    
    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 128
g_conv_dim = 128
z_size = 500

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv2): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=8192, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=500, out_features=2048, bias=True)
#   (deconvA): Sequential(
#     (0): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv0): Sequential(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim


lr = .0001
beta1= 0.1
beta2= 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
# ---------------------------------------------------------------------
            # 1. Train the discriminator on real and fake images
# ---------------------------------------------------------------------
            
# ---------------------------------------------
#             a) Real Images

            d_optimizer.zero_grad()
            
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
# ----------------------------------------------           
#             b) Fake Images

#             Generate fakes
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
#             Get Loss, Backpropogate
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()
            
# ---------------------------------------------------------------------
            # 2. Train the generator with an adversarial loss
# ---------------------------------------------------------------------
            g_optimizer.zero_grad()
            
#             Generate Fakes
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
#             Get Loss, Backpropogate
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        with torch.no_grad():
            samples_z = G(fixed_z)
            samples_z = samples_z.detach().cpu()
            samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 1.1791 | g_loss: 4.9119
# Epoch [    1/   50] | d_loss: 0.0209 | g_loss: 13.0569
# Epoch [    1/   50] | d_loss: 0.0335 | g_loss: 6.2131
# Epoch [    1/   50] | d_loss: 0.0120 | g_loss: 5.9698
# Epoch [    1/   50] | d_loss: 0.0151 | g_loss: 6.1214
# Epoch [    1/   50] | d_loss: 0.0057 | g_loss: 6.1458
# Epoch [    1/   50] | d_loss: 0.0050 | g_loss: 6.4995
# Epoch [    1/   50] | d_loss: 0.0040 | g_loss: 6.4836
# Epoch [    1/   50] | d_loss: 0.0034 | g_loss: 6.7057
# Epoch [    1/   50] | d_loss: 0.0023 | g_loss: 6.7811
# Epoch [    1/   50] | d_loss: 0.0024 | g_loss: 7.0290
# Epoch [    1/   50] | d_loss: 0.0019 | g_loss: 6.9968
# Epoch [    1/   50] | d_loss: 0.0017 | g_loss: 7.1367
# Epoch [    1/   50] | d_loss: 0.0011 | g_loss: 7.5049
# Epoch [    1/   50] | d_loss: 0.0008 | g_loss: 7.7008
# Epoch [    1/   50] | d_loss: 0.0009 | g_loss: 7.9124
# Epoch [    2/   50] | d_loss: 0.0011 | g_loss: 7.7719
# Epoch [    2/   50] | d_loss: 0.0006 | g_loss: 7.7894
# Epoch [    2/   50] | d_loss: 0.0009 | g_loss: 7.7881
# Epoch [    2/   50] | d_loss: 0.0004 | g_loss: 8.2141
# Epoch [    2/   50] | d_loss: 0.0006 | g_loss: 8.2539
# Epoch [    2/   50] | d_loss: 0.0007 | g_loss: 8.3138
# Epoch [    2/   50] | d_loss: 0.0004 | g_loss: 8.3457
# Epoch [    2/   50] | d_loss: 0.0004 | g_loss: 8.3890
# Epoch [    2/   50] | d_loss: 0.0003 | g_loss: 8.7352
# Epoch [    2/   50] | d_loss: 0.0002 | g_loss: 8.7770
# Epoch [    2/   50] | d_loss: 0.0003 | g_loss: 8.8060
# Epoch [    2/   50] | d_loss: 0.0002 | g_loss: 9.0725
# Epoch [    2/   50] | d_loss: 0.0003 | g_loss: 8.8055
# Epoch [    2/   50] | d_loss: 0.0003 | g_loss: 9.4878
# Epoch [    2/   50] | d_loss: 0.0002 | g_loss: 9.0124
# Epoch [    2/   50] | d_loss: 0.0002 | g_loss: 8.8267
# Epoch [    3/   50] | d_loss: 0.0003 | g_loss: 8.9760
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 8.9923
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 8.8878
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 8.8013
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 8.7799
# Epoch [    3/   50] | d_loss: 0.0003 | g_loss: 8.7577
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 9.0373
# Epoch [    3/   50] | d_loss: 0.0002 | g_loss: 9.1145
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.4914
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.5430
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.6746
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.6296
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 10.0531
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.9138
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 10.0972
# Epoch [    3/   50] | d_loss: 0.0001 | g_loss: 9.8026
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 9.9736
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 9.8887
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 9.7588
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 9.9580
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.0581
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.1871
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.4375
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.1142
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.1667
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.0373
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 9.9047
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.0830
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.3187
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.1781
# Epoch [    4/   50] | d_loss: 0.0000 | g_loss: 10.2466
# Epoch [    4/   50] | d_loss: 0.0001 | g_loss: 10.3688
# Epoch [    5/   50] | d_loss: 0.0001 | g_loss: 10.2385
# Epoch [    5/   50] | d_loss: 0.0001 | g_loss: 10.4050
# Epoch [    5/   50] | d_loss: 0.0001 | g_loss: 10.2237
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.5104
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.7674
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.8685
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.7215
# Epoch [    5/   50] | d_loss: 0.0001 | g_loss: 11.0226
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 11.1685
# Epoch [    5/   50] | d_loss: 0.0001 | g_loss: 10.9200
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.9159
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.8085
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 10.7971
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 11.1303
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 11.2280
# Epoch [    5/   50] | d_loss: 0.0000 | g_loss: 11.0399
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.1837
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.3199
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.3347
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.2755
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.4401
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.6866
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.4456
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.6133
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.8332
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.7438
# Epoch [    6/   50] | d_loss: 0.0001 | g_loss: 11.8046
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.7693
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 12.0857
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.9396
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 11.9568
# Epoch [    6/   50] | d_loss: 0.0000 | g_loss: 12.0624
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.0007
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.3012
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.2758
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.4903
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.3611
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.1268
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.2280
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.3495
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.2461
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.0056
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.1374
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 11.9384
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 12.1397
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 11.9857
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 11.7616
# Epoch [    7/   50] | d_loss: 0.0000 | g_loss: 11.8350
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.7337
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.8427
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.7704
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.8110
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.5414
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.7238
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.0680
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.0491
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.1560
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.9616
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.9580
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.0510
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.7921
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 11.7735
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.0342
# Epoch [    8/   50] | d_loss: 0.0000 | g_loss: 12.2184
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.0941
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.1197
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.1284
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.0895
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.1293
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.2502
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.3863
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.3152
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.5001
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 11.9805
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.2075
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.3615
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.5827
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.7153
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.6774
# Epoch [    9/   50] | d_loss: 0.0000 | g_loss: 12.5207
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 12.6680
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 12.6819
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 12.8857
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 12.9747
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 12.9262
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.1515
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.2010
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.2475
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.0032
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.2078
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.2746
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.4221
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.6857
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.7364
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.8917
# Epoch [   10/   50] | d_loss: 0.0000 | g_loss: 13.8882
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.3126
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.1810
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.3793
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5766
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.2614
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.3941
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.4502
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.2585
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5753
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.4109
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5469
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5155
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5231
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.4759
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.5300
# Epoch [   11/   50] | d_loss: 0.0000 | g_loss: 14.6559
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.6338
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.4497
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.7792
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.6855
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.5937
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.6857
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.4638
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.6550
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.7443
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.9197
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.7884
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 14.8665
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 15.1357
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 15.2041
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 15.1709
# Epoch [   12/   50] | d_loss: 0.0000 | g_loss: 15.0801
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.1934
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.2567
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.3663
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.5922
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.3354
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.4450
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.4624
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.5086
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.6022
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.4294
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.4578
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.4978
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.6177
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.7261
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.9390
# Epoch [   13/   50] | d_loss: 0.0000 | g_loss: 15.8938
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 15.9751
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 15.8744
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 15.9307
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 15.8966
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.0468
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 15.9926
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.1882
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.1866
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.2640
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.2336
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.2532
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.4666
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.1861
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.3455
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.4435
# Epoch [   14/   50] | d_loss: 0.0000 | g_loss: 16.4766
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.3006
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.6804
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.3734
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.7437
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.6398
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.5609
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.6840
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.9574
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.7744
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.5396
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.5087
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.9111
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.4274
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.7080
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.8325
# Epoch [   15/   50] | d_loss: 0.0000 | g_loss: 16.7369
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.7317
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.7591
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.9821
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.7795
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.6340
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.5216
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.6506
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.7839
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.9223
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.9195
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 17.0239
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 17.0715
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 16.9728
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 17.1248
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 17.0110
# Epoch [   16/   50] | d_loss: 0.0000 | g_loss: 17.2981
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.3219
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.4036
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 16.9587
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.1528
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.3990
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.0795
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.0648
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.4605
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.2127
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.2729
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.5919
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.4642
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.2844
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.3676
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.3909
# Epoch [   17/   50] | d_loss: 0.0000 | g_loss: 17.2841
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.2959
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.4561
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.3036
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.5764
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.4624
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.3991
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.4323
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.5285
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.5539
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.2700
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.1140
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.2721
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.1896
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.4050
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.1849
# Epoch [   18/   50] | d_loss: 0.0000 | g_loss: 17.5285
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.3604
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.4287
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.6360
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.6730
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.3885
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.7565
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.1928
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.1322
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.0043
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.4310
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.5821
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.3056
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.7186
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.7036
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.7179
# Epoch [   19/   50] | d_loss: 0.0000 | g_loss: 17.6089
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.6067
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.3690
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.4920
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.7019
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.4938
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.4608
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.4908
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.3607
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.1476
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.2608
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.1944
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.1477
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.0177
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.2570
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.2003
# Epoch [   20/   50] | d_loss: 0.0000 | g_loss: 17.1805
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 17.0898
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 17.2584
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 17.2591
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.8607
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 17.1227
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.7645
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.8798
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.8499
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.9421
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 17.0005
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.6678
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.4227
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.3192
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.6774
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.7157
# Epoch [   21/   50] | d_loss: 0.0000 | g_loss: 16.7241
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 16.7686
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.1812
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 16.9474
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.1214
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.2593
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.5302
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.8880
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.9767
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.8874
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.7878
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.4038
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.4820
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.5077
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.5438
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.5082
# Epoch [   22/   50] | d_loss: 0.0000 | g_loss: 17.6833
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 17.5073
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.0099
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.0209
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.0803
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.1628
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.2190
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.4212
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.2031
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.3950
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.2334
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.1790
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.3321
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.4068
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.8236
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.8232
# Epoch [   23/   50] | d_loss: 0.0000 | g_loss: 18.7540
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.8440
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.7216
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.7241
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.8438
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.7412
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.8221
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.8685
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.7828
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.0327
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 18.9260
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.0339
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.0581
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.4040
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.0436
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.5623
# Epoch [   24/   50] | d_loss: 0.0000 | g_loss: 19.1284
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3250
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.5490
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.4278
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.4450
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3247
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.5653
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3878
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3544
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.5087
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3903
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.3408
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.1684
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 19.0065
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 18.8799
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 18.6551
# Epoch [   25/   50] | d_loss: 0.0000 | g_loss: 18.6164
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.8234
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.6288
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.4495
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.5770
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.7302
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.5356
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.4317
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.3746
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.4756
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 19.0076
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.9545
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.9814
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.7175
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.5767
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.5284
# Epoch [   26/   50] | d_loss: 0.0000 | g_loss: 18.7647
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.0118
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 18.8005
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.0417
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 18.9032
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.2475
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.3692
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.5290
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.7917
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.7620
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.7784
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.7949
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.7716
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 20.1499
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 19.9592
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 20.1407
# Epoch [   27/   50] | d_loss: 0.0000 | g_loss: 20.3409
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.2755
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.4330
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.3311
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.4925
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.4751
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.4519
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.2846
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.5370
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.4423
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.6380
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.6187
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.5439
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.7358
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.8090
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.6982
# Epoch [   28/   50] | d_loss: 0.0000 | g_loss: 20.8857
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 20.9344
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 20.7942
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.0087
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.0003
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.0887
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.1004
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.1546
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.1418
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.1591
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.2855
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.3957
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.7447
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.4807
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.5370
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.8060
# Epoch [   29/   50] | d_loss: 0.0000 | g_loss: 21.7503
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.7057
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 22.0152
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.7402
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.7096
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.9002
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.8660
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.7693
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.8542
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.9883
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.9453
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.9726
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 22.0288
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 21.8707
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 22.2560
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 22.1120
# Epoch [   30/   50] | d_loss: 0.0000 | g_loss: 22.3155
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.2186
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.3822
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.1901
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.1339
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.4653
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.3747
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.5590
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.7301
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.5068
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.4720
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.6887
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.6392
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.6478
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.6845
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.9711
# Epoch [   31/   50] | d_loss: 0.0000 | g_loss: 22.9827
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.7690
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.8404
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.7998
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.2936
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.1665
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.1890
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.0282
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.1602
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.4059
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.1316
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.9659
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.8200
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.0458
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.9833
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 22.9988
# Epoch [   32/   50] | d_loss: 0.0000 | g_loss: 23.2145
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.0766
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.0413
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.2626
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 22.9272
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.2256
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.3489
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.0877
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.1895
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.2170
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.3540
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.2248
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.2676
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.1455
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.3336
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.4681
# Epoch [   33/   50] | d_loss: 0.0000 | g_loss: 23.0844
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.0882
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.0553
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.4122
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.2254
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3246
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.4569
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3557
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.7010
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.2079
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.4371
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3355
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3820
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3019
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.6688
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.3102
# Epoch [   34/   50] | d_loss: 0.0000 | g_loss: 23.4845
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.5997
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.3253
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.6940
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.2809
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.6002
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.1911
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.3585
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.1269
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.4936
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.1490
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.4889
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.3182
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.3726
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.5977
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.2807
# Epoch [   35/   50] | d_loss: 0.0000 | g_loss: 23.0860
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.3494
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.1563
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.4600
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.2338
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.3349
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.1805
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.0119
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 22.9625
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.0358
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.1212
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.1367
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.0296
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.6864
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.3439
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.4970
# Epoch [   36/   50] | d_loss: 0.0000 | g_loss: 23.1594
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.1459
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.3095
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.3646
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.2320
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.5198
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.2819
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.2103
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.4883
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.4661
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.5023
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.5019
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.2480
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.4162
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.2728
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.4841
# Epoch [   37/   50] | d_loss: 0.0000 | g_loss: 23.4550
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.5430
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.3195
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.4729
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.5461
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.2688
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.5569
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.6605
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.1779
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.5110
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.4211
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.5036
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.2596
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.2479
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.4300
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.3360
# Epoch [   38/   50] | d_loss: 0.0000 | g_loss: 23.3677
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.5063
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.8402
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.4526
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.5773
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.9108
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.6296
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.5806
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 24.0657
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.7263
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.9484
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 24.0535
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.9586
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.8872
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.9167
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.7930
# Epoch [   39/   50] | d_loss: 0.0000 | g_loss: 23.9087
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.7405
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.6200
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.7802
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.6867
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.6089
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.7307
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.7677
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.7419
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.8447
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 24.2162
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.9481
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 24.0136
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 23.9472
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 24.1789
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 24.0955
# Epoch [   40/   50] | d_loss: 0.0000 | g_loss: 24.1330
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.0577
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.1061
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.0106
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 23.8461
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 23.8135
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.0777
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.2091
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.0561
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 23.9994
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 23.9986
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.2604
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.2084
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.1777
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.1456
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.3327
# Epoch [   41/   50] | d_loss: 0.0000 | g_loss: 24.3458
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2512
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1195
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2568
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1503
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2127
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2959
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.3454
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1831
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1281
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2471
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.3487
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.2317
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1156
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 23.9630
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 23.9895
# Epoch [   42/   50] | d_loss: 0.0000 | g_loss: 24.1627
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.0915
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.5167
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.2779
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.5031
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.3882
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.7198
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.3896
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.5563
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.4624
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.4627
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.3991
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.3100
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.3262
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.4186
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.4160
# Epoch [   43/   50] | d_loss: 0.0000 | g_loss: 24.5063
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4275
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4381
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3492
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4341
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3197
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.6156
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3803
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3502
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4927
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.6220
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4347
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.6687
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3617
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4561
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.3340
# Epoch [   44/   50] | d_loss: 0.0000 | g_loss: 24.4963
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.3559
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.4362
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.3236
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.3371
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.3355
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.4040
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1479
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1968
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.0078
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1400
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.0843
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1118
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1932
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1795
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1907
# Epoch [   45/   50] | d_loss: 0.0000 | g_loss: 24.1925
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.2570
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.2675
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3380
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3486
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3605
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3265
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.4425
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3980
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.4276
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.6044
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.5556
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.5100
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.4254
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3245
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.5854
# Epoch [   46/   50] | d_loss: 0.0000 | g_loss: 24.3520
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.3961
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.3262
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.4678
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.2742
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.3851
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.1685
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.3112
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.2291
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.4620
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.1745
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 24.1774
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 23.8133
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 23.9937
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 23.9723
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 23.8283
# Epoch [   47/   50] | d_loss: 0.0000 | g_loss: 23.9185
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 23.7913
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1310
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 23.9073
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.0131
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1222
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1086
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.2013
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 23.8773
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 23.9105
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1503
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1788
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.2078
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1018
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.3080
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 24.1048
# Epoch [   48/   50] | d_loss: 0.0000 | g_loss: 23.9110
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 23.8882
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.1906
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.1275
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.0305
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.0919
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.2609
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.3886
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.5613
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.5407
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.7329
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.9068
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.7709
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.8557
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.7323
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.8409
# Epoch [   49/   50] | d_loss: 0.0000 | g_loss: 24.9665
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 24.8140
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 24.9139
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 24.9262
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 24.9934
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.0585
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 24.9464
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1969
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.0831
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.2580
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1311
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1350
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1167
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.0945
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1150
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.1737
# Epoch [   50/   50] | d_loss: 0.0000 | g_loss: 25.3923

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
